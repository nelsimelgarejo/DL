# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsimelgarejo/DL/blob/master/Nelsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -ltrh /content/drive/.shortcut-targets-by-id/1eSPuywHaCL56KeawPiMYWYj47Ewy_qqw/Proyecto_DL
# Out:
# total 2.9M
# -rw------- 1 root root 143K May 28 02:42 'Proyecto de curso DL 2021.pdf'
# drwx------ 2 root root 4.0K May 31 04:00  archivos_varios_bkp
# -rw------- 1 root root 666K Jun  2 03:51  FinancialPhraseBank-v1.0.zip
# drwx------ 3 root root 4.0K Jun  3 05:23  data
# drwx------ 2 root root 4.0K Jun  3 05:23  models
# drwx------ 2 root root 4.0K Jun  3 05:45  finbert
# drwx------ 2 root root 4.0K Jun  3 20:43  scripts
# -rw------- 1 root root 153K Jun  4 01:30  Grupo3-Propuesta-Proyecto.pdf
# -rw------- 1 root root  151 Jun 11 04:06  Grupo3-Propuesta-Proyecto.gdoc
# -rw------- 1 root root 151K Jun 13 01:54  PDL-NEL.ipynb
# -rw------- 1 root root 152K Jun 13 02:26  milton-ProyDL-AnalisisSentimiento.ipynb
# -rw------- 1 root root  151 Jun 15 01:19  Acceso_OverLeaf.docx.gdoc
# drwx------ 2 root root 4.0K Jun 19 04:50  Prueba
# -rw------- 1 root root  24K Jun 28 01:56  Bert.ipynb
# drwx------ 2 root root 4.0K Jun 28 02:10  modelos_bert
# ...

# %%
#declaramos las rutas
BASE_DIR = "/content/drive/.shortcut-targets-by-id/1eSPuywHaCL56KeawPiMYWYj47Ewy_qqw/Proyecto_DL"

# %%
# !pwd
# Out:
# /content

# %%
trainData = pd.read_csv(BASE_DIR + "/data/sentiment_data/train.csv", sep='\t', header = 0)

# %%
trainData
# Out:
#                                                    text     label
# 0     After the reporting period , BioTie North Amer...  positive
# 1     They will cover all Forest Industry 's units a...  negative
# 2     ( ADP News ) - Nov 28 , 2008 - Finnish power-s...  positive
# 3     Following the transaction , Lundbeck has world...  positive
# 4     A few employees would remain at the Oulu plant...   neutral
# ...                                                 ...       ...
# 3483  Nordea 's chairman of the board Hans Dalborg h...   neutral
# 3484  Revenue for the quarter totaled 27.4 billion ,...  negative
# 3485  According to Finnish Aktia Bank 's Managing Di...  positive
# 3486  Short-term licenses for the games cost as litt...   neutral
# 3487  Rautaruukki Corporation Stock exchange release...  positive
#
# [3488 rows x 2 columns]

# %%
text = " ".join([x for x in trainData.text])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## for neutral

text = " ".join([x for x in trainData.text[trainData.label=='neutral']])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## for negative

text = " ".join([x for x in trainData.text[trainData.label=='negative']])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## for positive

text = " ".join([x for x in trainData.text[trainData.label=='positive']])

wordcloud = WordCloud(background_color='white').generate(text)

plt.figure(figsize=(8,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
sns.countplot(trainData.label)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
trainData['label'].value_counts()
# Out:
# neutral     2075
# positive     988
# negative     425
# Name: label, dtype: int64

# %%
(trainData['label'].value_counts()/trainData['label'].count())*100
# Out:
# neutral     59.489679
# positive    28.325688
# negative    12.184633
# Name: label, dtype: float64

# %%
trainData['label'].value_counts()

# %%
g = trainData['label']
df = pd.concat([g.value_counts(),              
g.value_counts(normalize=True).mul(100)],axis=1,keys=('counts','percentage'))
print (df)
# Out:
#           counts  percentage
# neutral     2075   59.489679
# positive     988   28.325688
# negative     425   12.184633

# %%
df = pd.concat([trainData['label'].value_counts(),              
trainData.value_counts(normalize=True).mul(100)],axis=1,keys=('counts','percentage'))

print (df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-75eb5b25cfb8> in <module>()
#       1 df = pd.concat([trainData['label'].value_counts(),
# ----> 2 trainData.value_counts(normalize=True).mul(100)],axis=1,keys=('counts','percentage'))
#       3
#       4 print (df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     285     )
#     286
# --> 287     return op.get_result()
#     288
#     289
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     478
#     479                 index, columns = self.new_axes
# --> 480                 df = cons(data, index=index)
#     481                 df.columns = columns
#     482                 return df.__finalize__(self, method="concat")
#
# ...

# %%
g = data[Target_col_Y]
df = pd.concat([g.value_counts(),              
g.value_counts(normalize=True).mul(100)],axis=1,keys=('counts','percentage'))
